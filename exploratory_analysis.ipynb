# %% [markdown]
# ## Exploratory Data Analysis
#
# Use this notebook to get familiar with the datasets we have. There is 10 questions we need to answer during the EDA.
#
#
# We shouldn't limit our EDA to these 10 questions. Let's be creative :).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
#df_train = pd.read_csv('sample_submission.csv')
#df_train

# %%
import pandas as pd

df = pd.read_csv (r'/Users/cameronstevens/Documents/Midterm_project/flights_test.csv')
#prints full flights_tests dataframe will all columns
#print (df) 
df_flight_test = df[['fl_date', 'mkt_carrier', 'mkt_carrier_fl_num', 'origin', 'dest', 'crs_elapsed_time']]
#shows new dataframe with selected features

df_flight_test
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/17/br0vxrrx56l5tr56_62n59dc0000gn/T/ipykernel_10223/3280109611.py in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv (r'/Users/cameronstevens/Documents/Midterm_project/flights_test.csv')
#       4 #prints full flights_tests dataframe will all columns
#       5 #print (df)
#
# /opt/anaconda3/envs/lhlabs_env/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/anaconda3/envs/lhlabs_env/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /opt/anaconda3/envs/lhlabs_env/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /opt/anaconda3/envs/lhlabs_env/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /opt/anaconda3/envs/lhlabs_env/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /opt/anaconda3/envs/lhlabs_env/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /opt/anaconda3/envs/lhlabs_env/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# /opt/anaconda3/envs/lhlabs_env/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/cameronstevens/Documents/Midterm_project/flights_test.csv'

# %%
df_flight_test[['crs_elapsed_time']].describe()
# Out:
#        crs_elapsed_time
# count     660556.000000
# mean         140.918700
# std           71.570367
# min          -77.000000
# 25%           90.000000
# 50%          122.000000
# 75%          171.000000
# max          700.000000

# %%
#missing values in flight_tests dataframe
total_flight_test = df_flight_test.isnull().sum().sort_values(ascending=False)
percent_flight_test = (df_flight_test.isnull().sum()/df_flight_test.isnull().count()).sort_values(ascending=False)
missing_data_flight_test = pd.concat([total_flight_test, percent_flight_test], axis=1, keys=['Total', 'Percent'])
missing_data_flight_test.head(20)
# Out:
#                     Total  Percent
# crs_elapsed_time        0      0.0
# dest                    0      0.0
# origin                  0      0.0
# mkt_carrier_fl_num      0      0.0
# mkt_carrier             0      0.0
# fl_date                 0      0.0

# %%
df_flights = pd.read_csv (r'/Users/cameronstevens/Documents/Midterm_project/flights.csv')
#prints full flights dataframe will all columns
df_flights.head()
# Out:
#       fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0  2019-08-11                 WN                 WN          WN
# 1  2019-08-11                 WN                 WN          WN
# 2  2019-08-11                 WN                 WN          WN
# 3  2019-08-11                 WN                 WN          WN
# 4  2019-08-11                 WN                 WN          WN
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                2779                WN   N7831B               2779
# 1                3413                WN   N743SW               3413
# 2                4131                WN   N7738A               4131
# 3                4159                WN   N8538V               4159
# 4                4254                WN   N427WN               4254
#
#    origin_airport_id origin  ... distance  carrier_delay weather_delay  \
# 0              10800    BUR  ...      296            NaN           NaN
# 1              10800    BUR  ...      296            NaN           NaN
# 2              10800    BUR  ...      296            NaN           NaN
# 3              10800    BUR  ...      296            NaN           NaN
# 4              10800    BUR  ...      296            NaN           NaN
#
#   nas_delay  security_delay  late_aircraft_delay  first_dep_time  \
# 0       NaN             NaN                  NaN             NaN
# 1       NaN             NaN                  NaN             NaN
# 2       NaN             NaN                  NaN             NaN
# 3       NaN             NaN                  NaN             NaN
# 4       NaN             NaN                  NaN             NaN
#
#    total_add_gtime  longest_add_gtime  no_name
# 0              NaN                NaN      NaN
# 1              NaN                NaN      NaN
# 2              NaN                NaN      NaN
# 3              NaN                NaN      NaN
# 4              NaN                NaN      NaN
#
# [5 rows x 42 columns]

# %%
df_flights.columns
# Out:
# Index(['fl_date', 'mkt_unique_carrier', 'branded_code_share', 'mkt_carrier',
#        'mkt_carrier_fl_num', 'op_unique_carrier', 'tail_num',
#        'op_carrier_fl_num', 'origin_airport_id', 'origin', 'origin_city_name',
#        'dest_airport_id', 'dest', 'dest_city_name', 'crs_dep_time', 'dep_time',
#        'dep_delay', 'taxi_out', 'wheels_off', 'wheels_on', 'taxi_in',
#        'crs_arr_time', 'arr_time', 'arr_delay', 'cancelled',
#        'cancellation_code', 'diverted', 'dup', 'crs_elapsed_time',
#        'actual_elapsed_time', 'air_time', 'flights', 'distance',
#        'carrier_delay', 'weather_delay', 'nas_delay', 'security_delay',
#        'late_aircraft_delay', 'first_dep_time', 'total_add_gtime',
#        'longest_add_gtime', 'no_name'],
#       dtype='object')

# %%
len(df_flights.columns)
# Out:
# 42

# %%
#missing values in flight dataframe
total = df_flights.isnull().sum().sort_values(ascending=False)
percent = (df_flights.isnull().sum()/df_flights.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#                         Total   Percent
# no_name              15927485  1.000000
# total_add_gtime      15818552  0.993161
# longest_add_gtime    15818549  0.993161
# first_dep_time       15818547  0.993160
# cancellation_code    15658277  0.983098
# late_aircraft_delay  12918001  0.811051
# security_delay       12918001  0.811051
# nas_delay            12918001  0.811051
# weather_delay        12918001  0.811051
# carrier_delay        12918001  0.811051
# air_time               315221  0.019791
# arr_delay              311744  0.019573
# actual_elapsed_time    309157  0.019410
# taxi_in                281172  0.017653
# wheels_on              281162  0.017653
# arr_time               275079  0.017271
# taxi_out               273274  0.017157
# wheels_off             273264  0.017157
# dep_delay              263754  0.016560
# dep_time               258814  0.016250

# %%
#New datafram with selected features 

df_flights = df_flights[['fl_date' , 'op_unique_carrier', 'op_carrier_fl_num' , 'origin_airport_id', 'origin', 'dest_airport_id', 'dest', 'crs_dep_time' , 'dep_delay', 'taxi_out', 'crs_arr_time','arr_delay' , 'crs_elapsed_time' , 'actual_elapsed_time' , 'distance', 'carrier_delay', 'weather_delay','nas_delay', 'security_delay' ,'late_aircraft_delay']]

# %%
print(df_flights.isnull().sum())
# Out:
# fl_date                       0
# op_unique_carrier             0
# op_carrier_fl_num             0
# origin_airport_id             0
# origin                        0
# dest_airport_id               0
# dest                          0
# crs_dep_time                  0
# dep_delay                263754
# taxi_out                 273274
# crs_arr_time                  0
# arr_delay                311744
# crs_elapsed_time             20
# actual_elapsed_time      309157
# distance                      0
# carrier_delay          12918001
# weather_delay          12918001
# nas_delay              12918001
# security_delay         12918001
# late_aircraft_delay    12918001
# dtype: int64

# %%
df_passengers = pd.read_csv (r'/Users/cameronstevens/Documents/Midterm_project/passengers.csv')
#prints full passanger dataframe will all columns
df_passengers.head()
# Out:
#    departures_scheduled  departures_performed  payload  seats  passengers  \
# 0                     1                     1    13500     50           0
# 1                     1                     1    13500     50           0
# 2                     1                     1    18740     70          48
# 3                     1                     1    13500     50           0
# 4                     1                     1    15200     76           0
#
#    freight  mail  distance  ramp_to_ramp  air_time  ... dest_country  \
# 0        0     0       293            69        49  ...           US
# 1        0     0       522           129        82  ...           US
# 2        0     0        73            49        24  ...           US
# 3        0     0       604           134        92  ...           US
# 4        0     0       924           168       112  ...           US
#
#    dest_country_name aircraft_group aircraft_type aircraft_config  year  \
# 0      United States              6           629               1  2017
# 1      United States              6           629               1  2017
# 2      United States              6           631               1  2017
# 3      United States              6           629               1  2017
# 4      United States              6           673               1  2017
#
#    month  distance_group  class  data_source
# 0     11               1      F           DU
# 1     11               2      F           DU
# 2     11               1      F           DU
# 3     11               2      F           DU
# 4     11               2      F           DU
#
# [5 rows x 38 columns]

# %%
#missing values in passengers dataframe
total_passengers = df_passengers.isnull().sum().sort_values(ascending=False)
percent_passengers = (df_passengers.isnull().sum()/df_passengers.isnull().count()).sort_values(ascending=False)
missing_data_passengers = pd.concat([total_passengers, percent_passengers], axis=1, keys=['Total', 'Percent'])
missing_data_passengers.head(28)
# Out:
#                        Total  Percent
# data_source                0      0.0
# air_time                   0      0.0
# carrier_group              0      0.0
# carrier_name               0      0.0
# carrier                    0      0.0
# region                     0      0.0
# unique_carrier_name        0      0.0
# airline_id                 0      0.0
# unique_carrier             0      0.0
# ramp_to_ramp               0      0.0
# class                      0      0.0
# distance                   0      0.0
# mail                       0      0.0
# freight                    0      0.0
# passengers                 0      0.0
# seats                      0      0.0
# payload                    0      0.0
# departures_performed       0      0.0
# carrier_group_new          0      0.0
# origin_airport_id          0      0.0
# origin_city_market_id      0      0.0
# origin                     0      0.0
# distance_group             0      0.0
# month                      0      0.0
# year                       0      0.0
# aircraft_config            0      0.0
# aircraft_type              0      0.0
# aircraft_group             0      0.0

# %%
df_passengers = df_passengers.dropna()
#df_passengers.head()

# %%
#to show that the total_passengers = df_passengers.isnull().sum().sort_values(ascending=False)
percent_passengers = (df_passengers.isnull().sum()/df_passengers.isnull().count()).sort_values(ascending=False)
missing_data_passengers = pd.concat([total_passengers, percent_passengers], axis=1, keys=['Total', 'Percent'])
missing_data_passengers.head(20)
# Out:
#                       Total  Percent
# origin_country            3      0.0
# data_source               0      0.0
# air_time                  0      0.0
# carrier_name              0      0.0
# carrier                   0      0.0
# region                    0      0.0
# unique_carrier_name       0      0.0
# airline_id                0      0.0
# unique_carrier            0      0.0
# ramp_to_ramp              0      0.0
# carrier_group_new         0      0.0
# distance                  0      0.0
# mail                      0      0.0
# freight                   0      0.0
# passengers                0      0.0
# seats                     0      0.0
# payload                   0      0.0
# departures_performed      0      0.0
# carrier_group             0      0.0
# origin_airport_id         0      0.0

# %%
df_fuel_comsumption = pd.read_csv (r'/Users/cameronstevens/Documents/Midterm_project/fuel_comsumption.csv')
#prints full fuel consumption dataframe will all columns
df_fuel_comsumption = df_fuel_comsumption.dropna()
#df_fuel_comsumption.head()

# %%
#missing values in fuel consumption dataframe
total_fuel_comsumption = df_fuel_comsumption.isnull().sum().sort_values(ascending=False)
percent_fuel_comsumption = (df_fuel_comsumption.isnull().sum()/df_fuel_comsumption.isnull().count()).sort_values(ascending=False)
missing_fuel_comsumption = pd.concat([total_fuel_comsumption, percent_fuel_comsumption], axis=1, keys=['Total', 'Percent'])
missing_fuel_comsumption.head(20)
# Out:
#                    Total  Percent
# year                   0      0.0
# ts_gallons             0      0.0
# airline_id             0      0.0
# unique_carrier         0      0.0
# carrier                0      0.0
# carrier_name           0      0.0
# carrier_group_new      0      0.0
# sdomt_gallons          0      0.0
# satl_gallons           0      0.0
# spac_gallons           0      0.0
# slat_gallons           0      0.0
# sint_gallons           0      0.0
# tdomt_gallons          0      0.0
# total_cost             0      0.0
# tint_gallons           0      0.0
# total_gallons          0      0.0
# sdomt_cost             0      0.0
# satl_cost              0      0.0
# spac_cost              0      0.0
# slat_cost              0      0.0

# %%
df_fuel_comsumption = df_fuel_comsumption.dropna()
#df_fuel_comsumption.head()

# %%
#to show missing values have been removed from data fuel consumption dataframe
total_fuel_comsumption = df_fuel_comsumption.isnull().sum().sort_values(ascending=False)
percent_fuel_comsumption = (df_fuel_comsumption.isnull().sum()/df_fuel_comsumption.isnull().count()).sort_values(ascending=False)
missing_fuel_comsumption = pd.concat([total_fuel_comsumption, percent_fuel_comsumption], axis=1, keys=['Total', 'Percent'])
missing_fuel_comsumption.head(20)
# Out:
#                    Total  Percent
# year                   0      0.0
# ts_gallons             0      0.0
# airline_id             0      0.0
# unique_carrier         0      0.0
# carrier                0      0.0
# carrier_name           0      0.0
# carrier_group_new      0      0.0
# sdomt_gallons          0      0.0
# satl_gallons           0      0.0
# spac_gallons           0      0.0
# slat_gallons           0      0.0
# sint_gallons           0      0.0
# tdomt_gallons          0      0.0
# total_cost             0      0.0
# tint_gallons           0      0.0
# total_gallons          0      0.0
# sdomt_cost             0      0.0
# satl_cost              0      0.0
# spac_cost              0      0.0
# slat_cost              0      0.0

# %% [markdown]
# #### **Task 1**: Test the hypothesis that the delay is from Normal distribution. and that **mean** of the delay is 0. Be careful about the outliers.

# %% [markdown]
# #### **Task 2**: Is average/median monthly delay different during the year? If yes, which are months with the biggest delays and what could be the reason?

# %% [markdown]
# #### **Task 3**: Does the weather affect the delay?
# Use the API to pull the weather information for flights. There is no need to get weather for ALL flights. We can choose the right representative sample. Let's focus on four weather types:
# - sunny
# - cloudy
# - rainy
# - snow.
# Test the hypothesis that these 4 delays are from the same distribution. If they are not, which ones are significantly different?

# %% [markdown]
# #### **Task 4**: How taxi times changing during the day? Does higher traffic lead to bigger taxi times?

# %% [markdown]
# #### **Task 5**: What is the average percentage of delays that is already created before departure? (aka are arrival delays caused by departure delays?) Are airlines able to lower the delay during the flights?

# %% [markdown]
# #### **Task 6**: How many states cover 50% of US air traffic?

# %% [markdown]
# #### **Task 7**: Test the hypothesis whether planes fly faster when there is the departure delay?

# %% [markdown]
# #### **Task 8**: When (which hour) do most 'LONG', 'SHORT', 'MEDIUM' haul flights take off?

# %% [markdown]
# #### **Task 9**: Find the top 10 the bussiest airports. Does the biggest number of flights mean that the biggest number of passengers went through the particular airport? How much traffic do these 10 airports cover?

# %% [markdown]
# #### **Task 10**: Do bigger delays lead to bigger fuel comsumption per passenger?
# We need to do four things to answer this as accurate as possible:
# - Find out average monthly delay per air carrier (monthly delay is sum of all delays in 1 month)
# - Find out distance covered monthly by different air carriers
# - Find out number of passengers that were carried by different air carriers
# - Find out total fuel comsumption per air carrier.
#
# Use this information to get the average fuel comsumption per passenger per km. Is this higher for the airlines with bigger average delays?

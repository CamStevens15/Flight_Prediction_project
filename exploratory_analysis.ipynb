# %% [markdown]
# ## Exploratory Data Analysis
#
# Use this notebook to get familiar with the datasets we have. There is 10 questions we need to answer during the EDA.
#
#
# We shouldn't limit our EDA to these 10 questions. Let's be creative :).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
#Hello my name is cam

# %%
#df_train = pd.read_csv('sample_submission.csv')
#df_train

# %%
import pandas as pd

df = pd.read_csv (r'/Users/cameronstevens/Documents/Midterm_project/flights_test.csv')
#prints full flights_tests dataframe will all columns
#print (df)
#print(df.columns)

# %%
#missing values in flight_tests dataframe
total_flight_test = df_flight_test.isnull().sum().sort_values(ascending=False)
percent_flight_test = (df_flight_test.isnull().sum()/df_flight_test.isnull().count()).sort_values(ascending=False)
missing_data_flight_test = pd.concat([total_flight_test, percent_flight_test], axis=1, keys=['Total', 'Percent'])
#missing_data_flight_test.head(20)

# %%
df_flights_total = pd.read_csv (r'/Users/cameronstevens/Documents/Midterm_project/flights.csv')
#prints full flights dataframe will all columns
df_flights_total.head()
# Out:
#       fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0  2019-08-11                 WN                 WN          WN
# 1  2019-08-11                 WN                 WN          WN
# 2  2019-08-11                 WN                 WN          WN
# 3  2019-08-11                 WN                 WN          WN
# 4  2019-08-11                 WN                 WN          WN
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                2779                WN   N7831B               2779
# 1                3413                WN   N743SW               3413
# 2                4131                WN   N7738A               4131
# 3                4159                WN   N8538V               4159
# 4                4254                WN   N427WN               4254
#
#    origin_airport_id origin  ... distance  carrier_delay weather_delay  \
# 0              10800    BUR  ...      296            NaN           NaN
# 1              10800    BUR  ...      296            NaN           NaN
# 2              10800    BUR  ...      296            NaN           NaN
# 3              10800    BUR  ...      296            NaN           NaN
# 4              10800    BUR  ...      296            NaN           NaN
#
#   nas_delay  security_delay  late_aircraft_delay  first_dep_time  \
# 0       NaN             NaN                  NaN             NaN
# 1       NaN             NaN                  NaN             NaN
# 2       NaN             NaN                  NaN             NaN
# 3       NaN             NaN                  NaN             NaN
# 4       NaN             NaN                  NaN             NaN
#
#    total_add_gtime  longest_add_gtime  no_name
# 0              NaN                NaN      NaN
# 1              NaN                NaN      NaN
# 2              NaN                NaN      NaN
# 3              NaN                NaN      NaN
# 4              NaN                NaN      NaN
#
# [5 rows x 42 columns]

# %%
df_flights_total.columns
# Out:
# Index(['fl_date', 'mkt_unique_carrier', 'branded_code_share', 'mkt_carrier',
#        'mkt_carrier_fl_num', 'op_unique_carrier', 'tail_num',
#        'op_carrier_fl_num', 'origin_airport_id', 'origin', 'origin_city_name',
#        'dest_airport_id', 'dest', 'dest_city_name', 'crs_dep_time', 'dep_time',
#        'dep_delay', 'taxi_out', 'wheels_off', 'wheels_on', 'taxi_in',
#        'crs_arr_time', 'arr_time', 'arr_delay', 'cancelled',
#        'cancellation_code', 'diverted', 'dup', 'crs_elapsed_time',
#        'actual_elapsed_time', 'air_time', 'flights', 'distance',
#        'carrier_delay', 'weather_delay', 'nas_delay', 'security_delay',
#        'late_aircraft_delay', 'first_dep_time', 'total_add_gtime',
#        'longest_add_gtime', 'no_name'],
#       dtype='object')

# %%
len(df_flights_total.columns)
# Out:
# 42

# %%
#missing values in flight dataframe
total = df_flights_total.isnull().sum().sort_values(ascending=False)
percent = (df_flights_total.isnull().sum()/df_flights_total.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#                         Total   Percent
# no_name              15927485  1.000000
# total_add_gtime      15818552  0.993161
# longest_add_gtime    15818549  0.993161
# first_dep_time       15818547  0.993160
# cancellation_code    15658277  0.983098
# late_aircraft_delay  12918001  0.811051
# security_delay       12918001  0.811051
# nas_delay            12918001  0.811051
# weather_delay        12918001  0.811051
# carrier_delay        12918001  0.811051
# air_time               315221  0.019791
# arr_delay              311744  0.019573
# actual_elapsed_time    309157  0.019410
# taxi_in                281172  0.017653
# wheels_on              281162  0.017653
# arr_time               275079  0.017271
# taxi_out               273274  0.017157
# wheels_off             273264  0.017157
# dep_delay              263754  0.016560
# dep_time               258814  0.016250

# %%
#New datafram with selected features 

df_flights = df_flights_total[['fl_date', 'mkt_unique_carrier', 'branded_code_share', 'mkt_carrier',
       'mkt_carrier_fl_num', 'op_unique_carrier', 'tail_num',
       'op_carrier_fl_num', 'origin_airport_id', 'origin', 'origin_city_name',
       'dest_airport_id', 'dest', 'dest_city_name', 'crs_dep_time',
       'crs_arr_time', 'dup', 'crs_elapsed_time', 'flights', 'distance']]
df_flights.head()
# Out:
#       fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0  2019-08-11                 WN                 WN          WN
# 1  2019-08-11                 WN                 WN          WN
# 2  2019-08-11                 WN                 WN          WN
# 3  2019-08-11                 WN                 WN          WN
# 4  2019-08-11                 WN                 WN          WN
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                2779                WN   N7831B               2779
# 1                3413                WN   N743SW               3413
# 2                4131                WN   N7738A               4131
# 3                4159                WN   N8538V               4159
# 4                4254                WN   N427WN               4254
#
#    origin_airport_id origin origin_city_name  dest_airport_id dest  \
# 0              10800    BUR      Burbank, CA            14831  SJC
# 1              10800    BUR      Burbank, CA            14831  SJC
# 2              10800    BUR      Burbank, CA            14831  SJC
# 3              10800    BUR      Burbank, CA            14831  SJC
# 4              10800    BUR      Burbank, CA            14831  SJC
#
#   dest_city_name  crs_dep_time  crs_arr_time dup  crs_elapsed_time  flights  \
# 0   San Jose, CA           830           935   N              65.0        1
# 1   San Jose, CA          2050          2155   N              65.0        1
# 2   San Jose, CA          1020          1130   N              70.0        1
# 3   San Jose, CA          1325          1430   N              65.0        1
# 4   San Jose, CA          1650          1805   N              75.0        1
#
#    distance
# 0       296
# 1       296
# 2       296
# 3       296
# 4       296

# %%
#shows the top 5 carriers in the data which we will filter the data on, which will limit the amount of data overall

filtered_df= df_flights["op_unique_carrier"].value_counts()[:5].sort_values(ascending=False)
filtered_df
# Out:
# WN    2713963
# DL    1939694
# AA    1862100
# OO    1609494
# UA    1246563
# Name: op_unique_carrier, dtype: int64

# %%
#filter for top 5 carrier airlines to get data from.
flightsWN= df_flights.loc[df_flights['op_unique_carrier'] == "WN"]
flightsDL= df_flights.loc[df_flights['op_unique_carrier'] == "DL"]
flightsAA= df_flights.loc[df_flights['op_unique_carrier'] == "AA"]
flightsOO= df_flights.loc[df_flights['op_unique_carrier'] == "OO"]
flightsUA= df_flights.loc[df_flights['op_unique_carrier'] == "UA"]

# %%
#add datafames for % top carriers together

frames = [flightsWN, flightsDL, flightsAA, flightsOO,flightsUA]

result = pd.concat(frames)


#print 25000 samples from the top 5 carriers in the filtered total_flights dataframe
sampled_flights_df = result.sample(n = 25000)
sampled_flights_df.head()
# Out:
#              fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 5439856   2019-01-19                 AA                 AA          AA
# 12329743  2018-08-02                 WN                 WN          WN
# 11844139  2018-01-08                 UA                 UA          UA
# 11660663  2019-07-30                 DL                 DL          DL
# 6867725   2018-02-25                 WN                 WN          WN
#
#           mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 5439856                 2278                AA    N9012               2278
# 12329743                 117                WN   N209WN                117
# 11844139                1718                UA   N854UA               1718
# 11660663                3042                DL   N3762Y               3042
# 6867725                 4751                WN   N709SW               4751
#
#           origin_airport_id origin origin_city_name  dest_airport_id dest  \
# 5439856               11278    DCA   Washington, DC            13303  MIA
# 12329743              13342    MKE    Milwaukee, WI            14747  SEA
# 11844139              13930    ORD      Chicago, IL            11298  DFW
# 11660663              10397    ATL      Atlanta, GA            15304  TPA
# 6867725               14057    PDX     Portland, OR            14831  SJC
#
#                  dest_city_name  crs_dep_time  crs_arr_time dup  \
# 5439856               Miami, FL          1006          1259   N
# 12329743            Seattle, WA          1330          1550   N
# 11844139  Dallas/Fort Worth, TX          1755          2031   N
# 11660663              Tampa, FL           931          1101   N
# 6867725            San Jose, CA          2100          2245   N
#
#           crs_elapsed_time  flights  distance
# 5439856              173.0        1       919
# 12329743             260.0        1      1694
# 11844139             156.0        1       802
# 11660663              90.0        1       406
# 6867725              105.0        1       569

# %%
print(df_flights.isnull().sum())
# Out:
# fl_date                   0
# mkt_unique_carrier        0
# branded_code_share        0
# mkt_carrier               0
# mkt_carrier_fl_num        0
# op_unique_carrier         0
# tail_num              49269
# op_carrier_fl_num         0
# origin_airport_id         0
# origin                    0
# origin_city_name          0
# dest_airport_id           0
# dest                      0
# dest_city_name            0
# crs_dep_time              0
# crs_arr_time              0
# dup                       0
# crs_elapsed_time         20
# flights                   0
# distance                  0
# dtype: int64

# %%
len(sampled_flights_df)
# Out:
# 25000

# %%
#( Convert the date to datetime64)

df_flights['fl_date'] = pd.to_datetime(df_flights['fl_date'], format='%Y-%m-%d')
  
# Filter data between two dates
filtered_df = df_flights.loc[(df_flights['fl_date'] >= '2019-05-01')
                     & (df_flights['fl_date'] < '2019-12-31')]
# Display
filtered_df

# %%
sampled_flights_df['culmen_depth_mm'].fillna((sampled_flights_df['culmen_depth_mm'].mean()), inplace=True)

# %%
#export concatonated dataframes to a csv file

sampled_flights_df.to_csv('sampled_flights_csv')

# %% [markdown]
# ## Passenger dataframe:

# %%
df_passengers = pd.read_csv (r'/Users/cameronstevens/Documents/Midterm_project/passengers.csv')
#prints full passanger dataframe will all columns
df_passengers.head()
# Out:
#    departures_scheduled  departures_performed  payload  seats  passengers  \
# 0                     1                     1    13500     50           0
# 1                     1                     1    13500     50           0
# 2                     1                     1    18740     70          48
# 3                     1                     1    13500     50           0
# 4                     1                     1    15200     76           0
#
#    freight  mail  distance  ramp_to_ramp  air_time  ... dest_country  \
# 0        0     0       293            69        49  ...           US
# 1        0     0       522           129        82  ...           US
# 2        0     0        73            49        24  ...           US
# 3        0     0       604           134        92  ...           US
# 4        0     0       924           168       112  ...           US
#
#    dest_country_name aircraft_group aircraft_type aircraft_config  year  \
# 0      United States              6           629               1  2017
# 1      United States              6           629               1  2017
# 2      United States              6           631               1  2017
# 3      United States              6           629               1  2017
# 4      United States              6           673               1  2017
#
#    month  distance_group  class  data_source
# 0     11               1      F           DU
# 1     11               2      F           DU
# 2     11               1      F           DU
# 3     11               2      F           DU
# 4     11               2      F           DU
#
# [5 rows x 38 columns]

# %%
#missing values in passengers dataframe
total_passengers = df_passengers.isnull().sum().sort_values(ascending=False)
percent_passengers = (df_passengers.isnull().sum()/df_passengers.isnull().count()).sort_values(ascending=False)
missing_data_passengers = pd.concat([total_passengers, percent_passengers], axis=1, keys=['Total', 'Percent'])
missing_data_passengers.head()
# Out:
#                Total  Percent
# data_source        0      0.0
# air_time           0      0.0
# carrier_group      0      0.0
# carrier_name       0      0.0
# carrier            0      0.0

# %%
df_passengers = df_passengers.dropna()
#df_passengers.head()

# %%
#to show that the total_passengers = df_passengers.isnull().sum().sort_values(ascending=False)
percent_passengers = (df_passengers.isnull().sum()/df_passengers.isnull().count()).sort_values(ascending=False)
missing_data_passengers = pd.concat([total_passengers, percent_passengers], axis=1, keys=['Total', 'Percent'])
missing_data_passengers.head(20)
# Out:
#                       Total  Percent
# origin_country            3      0.0
# data_source               0      0.0
# air_time                  0      0.0
# carrier_name              0      0.0
# carrier                   0      0.0
# region                    0      0.0
# unique_carrier_name       0      0.0
# airline_id                0      0.0
# unique_carrier            0      0.0
# ramp_to_ramp              0      0.0
# carrier_group_new         0      0.0
# distance                  0      0.0
# mail                      0      0.0
# freight                   0      0.0
# passengers                0      0.0
# seats                     0      0.0
# payload                   0      0.0
# departures_performed      0      0.0
# carrier_group             0      0.0
# origin_airport_id         0      0.0

# %%
df_fuel_comsumption = pd.read_csv (r'/Users/cameronstevens/Documents/Midterm_project/fuel_comsumption.csv')
#prints full fuel consumption dataframe will all columns
df_fuel_comsumption = df_fuel_comsumption.dropna()
#df_fuel_comsumption.head()

# %%
#missing values in fuel consumption dataframe
total_fuel_comsumption = df_fuel_comsumption.isnull().sum().sort_values(ascending=False)
percent_fuel_comsumption = (df_fuel_comsumption.isnull().sum()/df_fuel_comsumption.isnull().count()).sort_values(ascending=False)
missing_fuel_comsumption = pd.concat([total_fuel_comsumption, percent_fuel_comsumption], axis=1, keys=['Total', 'Percent'])
missing_fuel_comsumption.head(20)
# Out:
#                    Total  Percent
# year                   0      0.0
# ts_gallons             0      0.0
# airline_id             0      0.0
# unique_carrier         0      0.0
# carrier                0      0.0
# carrier_name           0      0.0
# carrier_group_new      0      0.0
# sdomt_gallons          0      0.0
# satl_gallons           0      0.0
# spac_gallons           0      0.0
# slat_gallons           0      0.0
# sint_gallons           0      0.0
# tdomt_gallons          0      0.0
# total_cost             0      0.0
# tint_gallons           0      0.0
# total_gallons          0      0.0
# sdomt_cost             0      0.0
# satl_cost              0      0.0
# spac_cost              0      0.0
# slat_cost              0      0.0

# %%
df_fuel_comsumption = df_fuel_comsumption.dropna()
#df_fuel_comsumption.head()

# %%
#to show missing values have been removed from data fuel consumption dataframe
total_fuel_comsumption = df_fuel_comsumption.isnull().sum().sort_values(ascending=False)
percent_fuel_comsumption = (df_fuel_comsumption.isnull().sum()/df_fuel_comsumption.isnull().count()).sort_values(ascending=False)
missing_fuel_comsumption = pd.concat([total_fuel_comsumption, percent_fuel_comsumption], axis=1, keys=['Total', 'Percent'])
missing_fuel_comsumption.head(20)
# Out:
#                    Total  Percent
# year                   0      0.0
# ts_gallons             0      0.0
# airline_id             0      0.0
# unique_carrier         0      0.0
# carrier                0      0.0
# carrier_name           0      0.0
# carrier_group_new      0      0.0
# sdomt_gallons          0      0.0
# satl_gallons           0      0.0
# spac_gallons           0      0.0
# slat_gallons           0      0.0
# sint_gallons           0      0.0
# tdomt_gallons          0      0.0
# total_cost             0      0.0
# tint_gallons           0      0.0
# total_gallons          0      0.0
# sdomt_cost             0      0.0
# satl_cost              0      0.0
# spac_cost              0      0.0
# slat_cost              0      0.0

# %% [markdown]
# #### **Task 1**: Test the hypothesis that the delay is from Normal distribution. and that **mean** of the delay is 0. Be careful about the outliers.

# %% [markdown]
# #### **Task 2**: Is average/median monthly delay different during the year? If yes, which are months with the biggest delays and what could be the reason?

# %% [markdown]
# #### **Task 3**: Does the weather affect the delay?
# Use the API to pull the weather information for flights. There is no need to get weather for ALL flights. We can choose the right representative sample. Let's focus on four weather types:
# - sunny
# - cloudy
# - rainy
# - snow.
# Test the hypothesis that these 4 delays are from the same distribution. If they are not, which ones are significantly different?

# %% [markdown]
# #### **Task 4**: How taxi times changing during the day? Does higher traffic lead to bigger taxi times?

# %% [markdown]
# #### **Task 5**: What is the average percentage of delays that is already created before departure? (aka are arrival delays caused by departure delays?) Are airlines able to lower the delay during the flights?

# %% [markdown]
# #### **Task 6**: How many states cover 50% of US air traffic?

# %% [markdown]
# #### **Task 7**: Test the hypothesis whether planes fly faster when there is the departure delay?

# %% [markdown]
# #### **Task 8**: When (which hour) do most 'LONG', 'SHORT', 'MEDIUM' haul flights take off?

# %% [markdown]
# #### **Task 9**: Find the top 10 the bussiest airports. Does the biggest number of flights mean that the biggest number of passengers went through the particular airport? How much traffic do these 10 airports cover?

# %% [markdown]
# #### **Task 10**: Do bigger delays lead to bigger fuel comsumption per passenger?
# We need to do four things to answer this as accurate as possible:
# - Find out average monthly delay per air carrier (monthly delay is sum of all delays in 1 month)
# - Find out distance covered monthly by different air carriers
# - Find out number of passengers that were carried by different air carriers
# - Find out total fuel comsumption per air carrier.
#
# Use this information to get the average fuel comsumption per passenger per km. Is this higher for the airlines with bigger average delays?
